# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

import openweathermapy as ow
from pprint import pprint


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?appid={}".format(api_key)
units = "imperial"

container_list = []
print("Beginning Data Retrieval")
Record_counter = 1
Set = 1

for i, city in enumerate(cities):
    if(i%10 == 0 and i>=10):
        Set += 1
        Record_counter=0
    query_url = f"{base_url}&q={city}&units={units}"
    print("Processing Record %s of Set %s | %s" %(Record_counter, Set, city)) 
    Record_counter += 1
    try:
        weather=requests.get(query_url).json()

        temp = weather["main"]["temp"]
        date = weather["dt"]
        cntry = weather["sys"]["country"]
        humid = weather["main"]["humidity"]  
        cloud = weather["clouds"]["all"]
        wind = weather["wind"]["speed"]
        lat = weather ["coord"]["lat"]
        lng = weather ["coord"]["lon"]
        container_list.append({
            "City name":city,
            "Date":date,
            "Country":cntry,
            "Temperature":temp,
            "Humidity":humid,
            "Cloud":cloud,
            "Windspeed":wind,
            "Latitude":lat,
            "Longitude":lng 
        })
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | shenjiamen
# Processing Record 2 of Set 1 | manoel urbano
# Processing Record 3 of Set 1 | thunder bay
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | yerbogachen
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 2 | albany
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 2 | akyab
# City not found. Skipping...
# Processing Record 8 of Set 2 | leningradskiy
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 0 of Set 3 | skibbereen
# Processing Record 1 of Set 3 | henties bay
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | ukiah
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | mataura
# Processing Record 6 of Set 3 | whitehorse
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | sur
# Processing Record 0 of Set 4 | half moon bay
# Processing Record 1 of Set 4 | santa ana
# Processing Record 2 of Set 4 | pedernales
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | nizhniye vyazovyye
# Processing Record 5 of Set 4 | khandagayty
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | rikitea
# Processing Record 0 of Set 5 | slonim
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | puerto escondido
# Processing Record 4 of Set 5 | atuona
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | sisimiut
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 0 of Set 6 | kolpashevo
# Processing Record 1 of Set 6 | qaanaaq
# Processing Record 2 of Set 6 | bratsk
# Processing Record 3 of Set 6 | roald
# Processing Record 4 of Set 6 | hermanus
# Processing Record 5 of Set 6 | barra dos coqueiros
# Processing Record 6 of Set 6 | kapaa
# Processing Record 7 of Set 6 | langsa
# Processing Record 8 of Set 6 | llangefni
# Processing Record 9 of Set 6 | vila velha
# Processing Record 0 of Set 7 | bridlington
# Processing Record 1 of Set 7 | marawi
# Processing Record 2 of Set 7 | saint-francois
# Processing Record 3 of Set 7 | jamestown
# Processing Record 4 of Set 7 | korla
# City not found. Skipping...
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | lastoursville
# Processing Record 7 of Set 7 | hithadhoo
# Processing Record 8 of Set 7 | dikson
# Processing Record 9 of Set 7 | hobart
# Processing Record 0 of Set 8 | new norfolk
# Processing Record 1 of Set 8 | muros
# Processing Record 2 of Set 8 | tocopilla
# Processing Record 3 of Set 8 | passo de camaragibe
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | mar del plata
# Processing Record 6 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 8 | mahajanga
# Processing Record 8 of Set 8 | makinsk
# Processing Record 9 of Set 8 | hilo
# Processing Record 0 of Set 9 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 9 | sorong
# Processing Record 2 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 9 | carnarvon
# Processing Record 4 of Set 9 | makakilo city
# Processing Record 5 of Set 9 | kuytun
# Processing Record 6 of Set 9 | warrnambool
# Processing Record 7 of Set 9 | barrow
# Processing Record 8 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 9 | east london
# Processing Record 0 of Set 10 | cape town
# Processing Record 1 of Set 10 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 10 | kem
# Processing Record 3 of Set 10 | pangai
# Processing Record 4 of Set 10 | yenagoa
# Processing Record 5 of Set 10 | meulaboh
# Processing Record 6 of Set 10 | souillac
# Processing Record 7 of Set 10 | coolum beach
# Processing Record 8 of Set 10 | atasu
# Processing Record 9 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 0 of Set 11 | lompoc
# Processing Record 1 of Set 11 | nanortalik
# Processing Record 2 of Set 11 | oktyabrskiy
# Processing Record 3 of Set 11 | college
# Processing Record 4 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 11 | butaritari
# Processing Record 6 of Set 11 | vaike-maarja
# Processing Record 7 of Set 11 | chokurdakh
# Processing Record 8 of Set 11 | verkhnyaya pyshma
# Processing Record 9 of Set 11 | talcahuano
# Processing Record 0 of Set 12 | tasiilaq
# Processing Record 1 of Set 12 | kemijarvi
# City not found. Skipping...
# Processing Record 2 of Set 12 | nantucket
# Processing Record 3 of Set 12 | guymon
# Processing Record 4 of Set 12 | traralgon
# Processing Record 5 of Set 12 | touros
# Processing Record 6 of Set 12 | severo-kurilsk
# Processing Record 7 of Set 12 | nikolskoye
# Processing Record 8 of Set 12 | namanga
# Processing Record 9 of Set 12 | vaini
# Processing Record 0 of Set 13 | xuddur
# Processing Record 1 of Set 13 | tevaitoa
# Processing Record 2 of Set 13 | mogadishu
# Processing Record 3 of Set 13 | makokou
# Processing Record 4 of Set 13 | ambilobe
# Processing Record 5 of Set 13 | nyurba
# Processing Record 6 of Set 13 | halifax
# Processing Record 7 of Set 13 | thompson
# Processing Record 8 of Set 13 | talnakh
# Processing Record 9 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 0 of Set 14 | prainha
# Processing Record 1 of Set 14 | chuy
# Processing Record 2 of Set 14 | san cristobal
# Processing Record 3 of Set 14 | bredasdorp
# Processing Record 4 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 14 | kurmanayevka
# Processing Record 6 of Set 14 | bathsheba
# Processing Record 7 of Set 14 | castelo do piaui
# Processing Record 8 of Set 14 | sakakah
# City not found. Skipping...
# Processing Record 9 of Set 14 | verkhoyansk
# Processing Record 0 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | jeremoabo
# Processing Record 2 of Set 15 | ilhabela
# Processing Record 3 of Set 15 | gimli
# Processing Record 4 of Set 15 | puerto ayora
# Processing Record 5 of Set 15 | hasaki
# Processing Record 6 of Set 15 | tuatapere
# Processing Record 7 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 15 | coshocton
# Processing Record 9 of Set 15 | naze
# Processing Record 0 of Set 16 | nouakchott
# Processing Record 1 of Set 16 | tautira
# Processing Record 2 of Set 16 | mount barker
# Processing Record 3 of Set 16 | flinders
# Processing Record 4 of Set 16 | hobyo
# Processing Record 5 of Set 16 | anadyr
# Processing Record 6 of Set 16 | denpasar
# Processing Record 7 of Set 16 | goderich
# Processing Record 8 of Set 16 | berlevag
# Processing Record 9 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 0 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 17 | san jose
# Processing Record 2 of Set 17 | eganville
# Processing Record 3 of Set 17 | bowmore
# Processing Record 4 of Set 17 | aljezur
# Processing Record 5 of Set 17 | prince rupert
# Processing Record 6 of Set 17 | komatipoort
# Processing Record 7 of Set 17 | lebu
# Processing Record 8 of Set 17 | seara
# Processing Record 9 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 0 of Set 18 | tateyama
# Processing Record 1 of Set 18 | clyde river
# Processing Record 2 of Set 18 | mimongo
# Processing Record 3 of Set 18 | arraial do cabo
# Processing Record 4 of Set 18 | esperance
# Processing Record 5 of Set 18 | thiruvananthapuram
# Processing Record 6 of Set 18 | kakegawa
# Processing Record 7 of Set 18 | sao filipe
# Processing Record 8 of Set 18 | morehead
# Processing Record 9 of Set 18 | gazi
# Processing Record 0 of Set 19 | bolshaya martynovka
# Processing Record 1 of Set 19 | bethel
# Processing Record 2 of Set 19 | narsaq
# Processing Record 3 of Set 19 | rochegda
# Processing Record 4 of Set 19 | natal
# Processing Record 5 of Set 19 | buala
# Processing Record 6 of Set 19 | cabra
# Processing Record 7 of Set 19 | povenets
# Processing Record 8 of Set 19 | redlands
# Processing Record 9 of Set 19 | zhaocheng
# City not found. Skipping...
# Processing Record 0 of Set 20 | la ronge
# Processing Record 1 of Set 20 | zalantun
# Processing Record 2 of Set 20 | coquimbo
# Processing Record 3 of Set 20 | port hardy
# Processing Record 4 of Set 20 | sofiysk
# City not found. Skipping...
# Processing Record 5 of Set 20 | hameenlinna
# Processing Record 6 of Set 20 | airai
# Processing Record 7 of Set 20 | rio gallegos
# Processing Record 8 of Set 20 | nevers
# Processing Record 9 of Set 20 | pathein
# Processing Record 0 of Set 21 | ayer itam
# City not found. Skipping...
# Processing Record 1 of Set 21 | kavaratti
# Processing Record 2 of Set 21 | nome
# Processing Record 3 of Set 21 | samoded
# Processing Record 4 of Set 21 | saint-pierre
# Processing Record 5 of Set 21 | kavieng
# Processing Record 6 of Set 21 | qasigiannguit
# Processing Record 7 of Set 21 | washim
# Processing Record 8 of Set 21 | san policarpo
# Processing Record 9 of Set 21 | zhigansk
# Processing Record 0 of Set 22 | gainesville
# Processing Record 1 of Set 22 | bad ragaz
# Processing Record 2 of Set 22 | san andres
# Processing Record 3 of Set 22 | fujin
# Processing Record 4 of Set 22 | faanui
# Processing Record 5 of Set 22 | kaitangata
# Processing Record 6 of Set 22 | alamos
# Processing Record 7 of Set 22 | longyearbyen
# Processing Record 8 of Set 22 | merauke
# Processing Record 9 of Set 22 | asau
# City not found. Skipping...
# Processing Record 0 of Set 23 | hamilton
# Processing Record 1 of Set 23 | ahipara
# Processing Record 2 of Set 23 | alamosa
# Processing Record 3 of Set 23 | san pedro
# Processing Record 4 of Set 23 | saldanha
# Processing Record 5 of Set 23 | ponta do sol
# Processing Record 6 of Set 23 | praia
# Processing Record 7 of Set 23 | saint-joseph
# Processing Record 8 of Set 23 | biak
# Processing Record 9 of Set 23 | saint-philippe
# Processing Record 0 of Set 24 | crawfordsville
# Processing Record 1 of Set 24 | alcala la real
# Processing Record 2 of Set 24 | netrakona
# Processing Record 3 of Set 24 | kautokeino
# Processing Record 4 of Set 24 | shitkino
# Processing Record 5 of Set 24 | moron
# Processing Record 6 of Set 24 | baillif
# Processing Record 7 of Set 24 | xiangfan
# City not found. Skipping...
# Processing Record 8 of Set 24 | mont-joli
# Processing Record 9 of Set 24 | kamloops
# Processing Record 0 of Set 25 | chute-aux-outardes
# Processing Record 1 of Set 25 | chebarkul
# Processing Record 2 of Set 25 | mangla
# Processing Record 3 of Set 25 | san antonio
# Processing Record 4 of Set 25 | vostok
# Processing Record 5 of Set 25 | glasgow
# Processing Record 6 of Set 25 | iracoubo
# Processing Record 7 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 25 | west plains
# Processing Record 9 of Set 25 | port macquarie
# Processing Record 0 of Set 26 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 26 | beringovskiy
# Processing Record 2 of Set 26 | yulara
# Processing Record 3 of Set 26 | sibiti
# Processing Record 4 of Set 26 | mayo
# Processing Record 5 of Set 26 | inyonga
# Processing Record 6 of Set 26 | ribas do rio pardo
# Processing Record 7 of Set 26 | norman wells
# Processing Record 8 of Set 26 | lagoa
# Processing Record 9 of Set 26 | hami
# Processing Record 0 of Set 27 | oussouye
# Processing Record 1 of Set 27 | winneba
# Processing Record 2 of Set 27 | acapulco
# Processing Record 3 of Set 27 | colquechaca
# Processing Record 4 of Set 27 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 27 | bembereke
# Processing Record 6 of Set 27 | otavi
# Processing Record 7 of Set 27 | linguere
# City not found. Skipping...
# Processing Record 8 of Set 27 | cidreira
# Processing Record 9 of Set 27 | rockingham
# Processing Record 0 of Set 28 | honningsvag
# Processing Record 1 of Set 28 | hope
# Processing Record 2 of Set 28 | alamogordo
# Processing Record 3 of Set 28 | kirakira
# Processing Record 4 of Set 28 | srednekolymsk
# Processing Record 5 of Set 28 | olafsvik
# City not found. Skipping...
# Processing Record 6 of Set 28 | ilam
# Processing Record 7 of Set 28 | pyay
# Processing Record 8 of Set 28 | sinnar
# Processing Record 9 of Set 28 | awbari
# Processing Record 0 of Set 29 | belmonte
# Processing Record 1 of Set 29 | przhevalskoye
# Processing Record 2 of Set 29 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 3 of Set 29 | lorengau
# Processing Record 4 of Set 29 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 29 | avarua
# Processing Record 6 of Set 29 | thayetmyo
# Processing Record 7 of Set 29 | abu dhabi
# Processing Record 8 of Set 29 | tres arroyos
# Processing Record 9 of Set 29 | cihuatlan
# Processing Record 0 of Set 30 | whitianga
# Processing Record 1 of Set 30 | darovskoy
# Processing Record 2 of Set 30 | muisne
# Processing Record 3 of Set 30 | la asuncion
# Processing Record 4 of Set 30 | bezopasnoye
# Processing Record 5 of Set 30 | yazykovo
# Processing Record 6 of Set 30 | katsuura
# Processing Record 7 of Set 30 | gayny
# Processing Record 8 of Set 30 | sao joao da barra
# Processing Record 9 of Set 30 | dharchula
# Processing Record 0 of Set 31 | krasnoarmeysk
# Processing Record 1 of Set 31 | curup
# Processing Record 2 of Set 31 | barra do garcas
# Processing Record 3 of Set 31 | dianopolis
# City not found. Skipping...
# Processing Record 4 of Set 31 | bibiani
# Processing Record 5 of Set 31 | contai
# Processing Record 6 of Set 31 | la rioja
# Processing Record 7 of Set 31 | nuuk
# Processing Record 8 of Set 31 | waingapu
# Processing Record 9 of Set 31 | ust-kut
# Processing Record 0 of Set 32 | salalah
# Processing Record 1 of Set 32 | qui nhon
# City not found. Skipping...
# Processing Record 2 of Set 32 | koslan
# Processing Record 3 of Set 32 | dali
# Processing Record 4 of Set 32 | turukhansk
# Processing Record 5 of Set 32 | namibe
# Processing Record 6 of Set 32 | port augusta
# Processing Record 7 of Set 32 | chapais
# Processing Record 8 of Set 32 | tiksi
# Processing Record 9 of Set 32 | palmer
# Processing Record 0 of Set 33 | mitu
# Processing Record 1 of Set 33 | chalon-sur-saone
# Processing Record 2 of Set 33 | saint george
# Processing Record 3 of Set 33 | provideniya
# Processing Record 4 of Set 33 | oliva
# Processing Record 5 of Set 33 | port lincoln
# Processing Record 6 of Set 33 | buenos aires
# Processing Record 7 of Set 33 | reinosa
# Processing Record 8 of Set 33 | taunggyi
# Processing Record 9 of Set 33 | takoradi
# Processing Record 0 of Set 34 | ostrovnoy
# Processing Record 1 of Set 34 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 34 | fukue
# Processing Record 3 of Set 34 | erzin
# Processing Record 4 of Set 34 | broome
# Processing Record 5 of Set 34 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 34 | flin flon
# Processing Record 7 of Set 34 | mount darwin
# Processing Record 8 of Set 34 | vaxjo
# City not found. Skipping...
# Processing Record 9 of Set 34 | assela
# City not found. Skipping...
# Processing Record 0 of Set 35 | matagami
# Processing Record 1 of Set 35 | baykit
# Processing Record 2 of Set 35 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 35 | gat
# Processing Record 4 of Set 35 | geraldton
# Processing Record 5 of Set 35 | ardakan
# Processing Record 6 of Set 35 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 35 | padang
# Processing Record 8 of Set 35 | codajas
# Processing Record 9 of Set 35 | agirish
# Processing Record 0 of Set 36 | kalmunai
# Processing Record 1 of Set 36 | evensk
# Processing Record 2 of Set 36 | anito
# Processing Record 3 of Set 36 | te anau
# Processing Record 4 of Set 36 | bandar
# Processing Record 5 of Set 36 | oranjemund
# Processing Record 6 of Set 36 | kamaishi
# Processing Record 7 of Set 36 | mandalgovi
# Processing Record 8 of Set 36 | briancon
# Processing Record 9 of Set 36 | burica
# City not found. Skipping...
# Processing Record 0 of Set 37 | cubuk
# Processing Record 1 of Set 37 | yumen
# Processing Record 2 of Set 37 | araure
# Processing Record 3 of Set 37 | hambantota
# Processing Record 4 of Set 37 | codrington
# Processing Record 5 of Set 37 | husavik
# Processing Record 6 of Set 37 | riberalta
# Processing Record 7 of Set 37 | santa rosa
# Processing Record 8 of Set 37 | novikovo
# Processing Record 9 of Set 37 | berbera
# City not found. Skipping...
# Processing Record 0 of Set 38 | tiznit
# Processing Record 1 of Set 38 | santa rosalia
# Processing Record 2 of Set 38 | fortuna
# Processing Record 3 of Set 38 | lubango
# Processing Record 4 of Set 38 | ribeirao branco
# Processing Record 5 of Set 38 | ketchikan
# Processing Record 6 of Set 38 | rudnogorsk
# Processing Record 7 of Set 38 | launceston
# Processing Record 8 of Set 38 | cedar city
# Processing Record 9 of Set 38 | cananea
# Processing Record 0 of Set 39 | angouleme
# Processing Record 1 of Set 39 | egvekinot
# Processing Record 2 of Set 39 | pudozh
# Processing Record 3 of Set 39 | sitka
# Processing Record 4 of Set 39 | laguna de perlas
# Processing Record 5 of Set 39 | varhaug
# Processing Record 6 of Set 39 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 39 | pangnirtung
# Processing Record 8 of Set 39 | sangar
# Processing Record 9 of Set 39 | maltahohe
# Processing Record 0 of Set 40 | mahibadhoo
# Processing Record 1 of Set 40 | omagari
# Processing Record 2 of Set 40 | novosokolniki
# Processing Record 3 of Set 40 | boa vista
# Processing Record 4 of Set 40 | martinho campos
# Processing Record 5 of Set 40 | chumikan
# Processing Record 6 of Set 40 | seka
# Processing Record 7 of Set 40 | mount isa
# Processing Record 8 of Set 40 | salinopolis
# Processing Record 9 of Set 40 | dhidhdhoo
# Processing Record 0 of Set 41 | koumac
# Processing Record 1 of Set 41 | nogliki
# Processing Record 2 of Set 41 | ust-tsilma
# Processing Record 3 of Set 41 | dapaong
# Processing Record 4 of Set 41 | mayumba
# Processing Record 5 of Set 41 | zhangye
# Processing Record 6 of Set 41 | acari
# Processing Record 7 of Set 41 | amuntai
# Processing Record 8 of Set 41 | komsomolskiy
# Processing Record 9 of Set 41 | vila franca do campo
# Processing Record 0 of Set 42 | la vega
# Processing Record 1 of Set 42 | yeppoon
# Processing Record 2 of Set 42 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 42 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 42 | fairbanks
# Processing Record 5 of Set 42 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 42 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 42 | ilulissat
# Processing Record 8 of Set 42 | pisco
# Processing Record 9 of Set 42 | san carlos de bariloche
# Processing Record 0 of Set 43 | san patricio
# Processing Record 1 of Set 43 | ofaqim
# Processing Record 2 of Set 43 | paamiut
# Processing Record 3 of Set 43 | barcarena
# Processing Record 4 of Set 43 | easthampton
# Processing Record 5 of Set 43 | coahuayana
# Processing Record 6 of Set 43 | richards bay
# Processing Record 7 of Set 43 | monte carmelo
# Processing Record 8 of Set 43 | cairns
# Processing Record 9 of Set 43 | manokwari
# Processing Record 0 of Set 44 | babanusah
# City not found. Skipping...
# Processing Record 1 of Set 44 | phonhong
# Processing Record 2 of Set 44 | novobirilyussy
# Processing Record 3 of Set 44 | baruun-urt
# Processing Record 4 of Set 44 | bend
# Processing Record 5 of Set 44 | acarau
# City not found. Skipping...
# Processing Record 6 of Set 44 | tutoia
# Processing Record 7 of Set 44 | vila
# Processing Record 8 of Set 44 | monte alegre
# Processing Record 9 of Set 44 | dekar
# Processing Record 0 of Set 45 | amparafaravola
# Processing Record 1 of Set 45 | shingu
# Processing Record 2 of Set 45 | gashua
# Processing Record 3 of Set 45 | camargo
# Processing Record 4 of Set 45 | miri
# Processing Record 5 of Set 45 | bac lieu
# City not found. Skipping...
# Processing Record 6 of Set 45 | kalabagh
# Processing Record 7 of Set 45 | comodoro rivadavia
# Processing Record 8 of Set 45 | veraval
# Processing Record 9 of Set 45 | bosansko grahovo
# Processing Record 0 of Set 46 | sao francisco
# Processing Record 1 of Set 46 | yar-sale
# Processing Record 2 of Set 46 | nuevo progreso
# Processing Record 3 of Set 46 | ketrzyn
# Processing Record 4 of Set 46 | methoni
# Processing Record 5 of Set 46 | boyolangu
# Processing Record 6 of Set 46 | birin
# Processing Record 7 of Set 46 | kofarnihon
# City not found. Skipping...
# Processing Record 8 of Set 46 | beyneu
# Processing Record 9 of Set 46 | richard toll
# City not found. Skipping...
# Processing Record 0 of Set 47 | am timan
# Processing Record 1 of Set 47 | linchuan
# City not found. Skipping...
# Processing Record 2 of Set 47 | ouallam
# Processing Record 3 of Set 47 | batagay
# Processing Record 4 of Set 47 | inhambane
# Processing Record 5 of Set 47 | orbetello
# Processing Record 6 of Set 47 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 47 | mudyuga
# City not found. Skipping...
# Processing Record 8 of Set 47 | victoria
# Processing Record 9 of Set 47 | bamiantong
# Processing Record 0 of Set 48 | china
# Processing Record 1 of Set 48 | correia pinto
# Processing Record 2 of Set 48 | tamandare
# Processing Record 3 of Set 48 | lithgow
# Processing Record 4 of Set 48 | mlalo
# Processing Record 5 of Set 48 | witrivier
# City not found. Skipping...
# Processing Record 6 of Set 48 | baturaja
# Processing Record 7 of Set 48 | ada
# Processing Record 8 of Set 48 | plouzane
# Processing Record 9 of Set 48 | ballina
# Processing Record 0 of Set 49 | rengo
# Processing Record 1 of Set 49 | nelson bay
# Processing Record 2 of Set 49 | rocha
# Processing Record 3 of Set 49 | calvinia
# Processing Record 4 of Set 49 | kapoeta
# City not found. Skipping...
# Processing Record 5 of Set 49 | port-gentil
# Processing Record 6 of Set 49 | marmaris
# Processing Record 7 of Set 49 | andenes
# City not found. Skipping...
# Processing Record 8 of Set 49 | tambura
# City not found. Skipping...
# Processing Record 9 of Set 49 | seoul
# Processing Record 0 of Set 50 | hondo
# Processing Record 1 of Set 50 | kencong
# Processing Record 2 of Set 50 | zhigalovo
# Processing Record 3 of Set 50 | springfield
# Processing Record 4 of Set 50 | high level
# Processing Record 5 of Set 50 | puerto quijarro
# Processing Record 6 of Set 50 | ambovombe
# Processing Record 7 of Set 50 | broken hill
# Processing Record 8 of Set 50 | imbituba
# Processing Record 9 of Set 50 | port said
# Processing Record 0 of Set 51 | carutapera
# Processing Record 1 of Set 51 | cherskiy
# Processing Record 2 of Set 51 | ulundi
# Processing Record 3 of Set 51 | sayan
# Processing Record 4 of Set 51 | churhat
# Processing Record 5 of Set 51 | ende
# Processing Record 6 of Set 51 | nouadhibou
# Processing Record 7 of Set 51 | phalaborwa
# Processing Record 8 of Set 51 | bud
# Processing Record 9 of Set 51 | teonthar
# Processing Record 0 of Set 52 | west wendover
# Processing Record 1 of Set 52 | rundu
# Processing Record 2 of Set 52 | bardiyah
# City not found. Skipping...
# Processing Record 3 of Set 52 | quanzhou
# Processing Record 4 of Set 52 | huambo
# Processing Record 5 of Set 52 | balkhash
# Processing Record 6 of Set 52 | grindavik
# Processing Record 7 of Set 52 | viedma
# Processing Record 8 of Set 52 | boda
# Processing Record 9 of Set 52 | oltu
# Processing Record 0 of Set 53 | cacapava
# Processing Record 1 of Set 53 | safranbolu
# Processing Record 2 of Set 53 | homer
# Processing Record 3 of Set 53 | aykhal
# Processing Record 4 of Set 53 | greenville
# Processing Record 5 of Set 53 | ruteng
# Processing Record 6 of Set 53 | bikaner
# Processing Record 7 of Set 53 | mahina
# Processing Record 8 of Set 53 | ust-ishim
# Processing Record 9 of Set 53 | green river
# Processing Record 0 of Set 54 | gotsu
# Processing Record 1 of Set 54 | lagunas
# Processing Record 2 of Set 54 | ostersund
# Processing Record 3 of Set 54 | condado
# Processing Record 4 of Set 54 | pyinmana
# Processing Record 5 of Set 54 | ayan
# Processing Record 6 of Set 54 | luderitz
# Processing Record 7 of Set 54 | kahului
# Processing Record 8 of Set 54 | leh
# Processing Record 9 of Set 54 | brae
# Processing Record 0 of Set 55 | ingham
# Processing Record 1 of Set 55 | uralets
# Processing Record 2 of Set 55 | amga
# Processing Record 3 of Set 55 | pitimbu
# Processing Record 4 of Set 55 | vallenar
# Processing Record 5 of Set 55 | champerico
# Processing Record 6 of Set 55 | tukrah
# City not found. Skipping...
# Processing Record 7 of Set 55 | adeje
# Processing Record 8 of Set 55 | churachandpur
# Processing Record 9 of Set 55 | riyadh
# Processing Record 0 of Set 56 | constitucion
# Processing Record 1 of Set 56 | keti bandar
# Processing Record 2 of Set 56 | nisia floresta
# Processing Record 3 of Set 56 | taoudenni
# Processing Record 4 of Set 56 | pacific grove
# Processing Record 5 of Set 56 | manggar
# Processing Record 6 of Set 56 | mbamba
# Processing Record 7 of Set 56 | genhe
# Processing Record 8 of Set 56 | gbarnga
# Processing Record 9 of Set 56 | petit goave
# Processing Record 0 of Set 57 | pemangkat
# City not found. Skipping...
# Processing Record 1 of Set 57 | guerrero negro
# Processing Record 2 of Set 57 | qaqortoq
# Processing Record 3 of Set 57 | la ligua
# Processing Record 4 of Set 57 | sao sebastiao
# Processing Record 5 of Set 57 | arawa
# Processing Record 6 of Set 57 | taltal
# Processing Record 7 of Set 57 | saint-nazaire
# Processing Record 8 of Set 57 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 57 | morondava
# Processing Record 0 of Set 58 | kuloy
# Processing Record 1 of Set 58 | birao
# Processing Record 2 of Set 58 | soyo
# Processing Record 3 of Set 58 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 58 | benguela
# Processing Record 5 of Set 58 | coihaique
# Processing Record 6 of Set 58 | bonavista
# Processing Record 7 of Set 58 | itamaraca
# Processing Record 8 of Set 58 | kruisfontein
# Processing Record 9 of Set 58 | teguldet
# Processing Record 0 of Set 59 | vestmannaeyjar
# Processing Record 1 of Set 59 | awjilah
# Processing Record 2 of Set 59 | aripuana
# Processing Record 3 of Set 59 | thinadhoo
# Processing Record 4 of Set 59 | port hedland
# Processing Record 5 of Set 59 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 59 | winslow
# Processing Record 7 of Set 59 | mirabad
# Processing Record 8 of Set 59 | shimanovsk
# Processing Record 9 of Set 59 | garhakota
# Processing Record 0 of Set 60 | kizukuri
# Processing Record 1 of Set 60 | sabha
# Processing Record 2 of Set 60 | kudahuvadhoo
# Processing Record 3 of Set 60 | ordzhonikidze
# Processing Record 4 of Set 60 | kaeo
# Processing Record 5 of Set 60 | kununurra
# Processing Record 6 of Set 60 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 60 | sechura
# Processing Record 8 of Set 60 | dien bien
# City not found. Skipping...
# Processing Record 9 of Set 60 | gizo
# Processing Record 0 of Set 61 | moose factory
# Processing Record 1 of Set 61 | vilhena
# Processing Record 2 of Set 61 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 61 | luanda
# Processing Record 4 of Set 61 | turayf
# Processing Record 5 of Set 61 | gisborne
# Processing Record 6 of Set 61 | porto-vecchio
# Processing Record 7 of Set 61 | guanare
# Processing Record 8 of Set 61 | adrar
# Processing Record 9 of Set 61 | calabar
# Processing Record 0 of Set 62 | pringsewu
# Processing Record 1 of Set 62 | camocim
# Processing Record 2 of Set 62 | yunyang
# Processing Record 3 of Set 62 | embonas
# City not found. Skipping...
# Processing Record 4 of Set 62 | moussoro
# Processing Record 5 of Set 62 | kenai
# Processing Record 6 of Set 62 | khani
# Processing Record 7 of Set 62 | road town
# Processing Record 8 of Set 62 | poya
# Processing Record 9 of Set 62 | polunochnoye
# Processing Record 0 of Set 63 | sioux lookout
# Processing Record 1 of Set 63 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 63 | zhezkazgan
# Processing Record 3 of Set 63 | sungaipenuh
# Processing Record 4 of Set 63 | wanning
# Processing Record 5 of Set 63 | reporoa
# Processing Record 6 of Set 63 | chara
# Processing Record 7 of Set 63 | mantua
# Processing Record 8 of Set 63 | sistranda
# Processing Record 9 of Set 63 | siyabuswa
# Processing Record 0 of Set 64 | ust-omchug
# Processing Record 1 of Set 64 | chimoio
# Processing Record 2 of Set 64 | marrakesh
# Processing Record 3 of Set 64 | praia da vitoria
# Processing Record 4 of Set 64 | eatonton

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame(container_list)
city = cities_df["City name"]
cntry = cities_df["Country"]
date = cities_df["Date"]
temp = cities_df["Temperature"]
humidity = cities_df["Humidity"]
cloud = cities_df["Cloud"]
wind = cities_df["Windspeed"]
lat = cities_df["Latitude"]
lat = cities_df["Longitude"]
cities_df.head()
# Out:
#         City name  Cloud Country        Date  Humidity  Latitude  Longitude  \
# 0      shenjiamen     20      CN  1554425966        98     29.96     122.30
# 1   manoel urbano      8      BR  1554426399        87     -8.84     -69.26
# 2     thunder bay     75      CA  1554426179        63     48.41     -89.26
# 3  port elizabeth      1      US  1554425838        40     39.31     -74.98
# 4     yerbogachen     76      RU  1554425920        86     61.28     108.01
#
#    Temperature  Windspeed
# 0        55.79      11.54
# 1        80.00       2.37
# 2        29.70      10.29
# 3        51.91       4.70
# 4        23.75       4.27

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
plt.scatter(lat, temp, color = "g", alpha = .8, marker = "o", edgecolor = "black")
plt.title("City Latitude Vs Temperature") 
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.grid(True)
plt.savefig("Weather_images/City latitude Vs Temperature")

# %%
plt.scatter(lat, humidity, color = "g", alpha = .8, marker = "o", edgecolor = "black")
plt.title("City Latitude Vs Humidity") 
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("Weather_images/City latitude Vs Humidity")

# %%
plt.scatter(lat, cloud, color = "g", alpha = .8, marker = "o", edgecolor = "black")   
plt.title("City Latitude Vs Cloudiness") 
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("Weather_images/City latitude Vs Cloudiness")

# %%
plt.scatter(lat, wind, color = "g", alpha = .8, marker = "o", edgecolor = "black")
plt.title("City Latitude Vs Wind Speed") 
plt.xlabel("Latitude")
plt.ylabel("Wind (mph)")
plt.grid(True)
plt.savefig("Weather_images/City Latitude Vs Wind")

# %%
cities_df.to_csv("CitiesWeather_Output.csv")
cities_df.head(2)
# Out:
#        City name  Cloud Country        Date  Humidity  Latitude  Longitude  \
# 0     shenjiamen     20      CN  1554425966        98     29.96     122.30
# 1  manoel urbano      8      BR  1554426399        87     -8.84     -69.26
#
#    Temperature  Windspeed
# 0        55.79      11.54
# 1        80.00       2.37
